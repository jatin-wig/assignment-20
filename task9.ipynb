# %% [markdown]
# 1. The application was successfully deployed on Render
#
# 2. The recommendation engine generated similar comments using TF-IDF and cosine similarity
#
# 3. Recommendations were tested on multiple comments and returned relevant results
#
# 4. Deployment URL:
